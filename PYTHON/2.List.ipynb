# %%
#Lists
#Ordered Sequences that hols variety of object types.
# [] notation used.
#Supports : 1.Indexing 2.Slicing 3.Nesting.

# %%
my_list=['sakigo',21,['saket','prag'],78.98]

# %%
my_list
# Out:
# ['sakigo', 21, ['saket', 'prag'], 78.98]

# %%
my_list[2][1]
# Out:
# 'prag'

# %%
my_list[::-1]
# Out:
# [78.98, ['saket', 'prag'], 21, 'sakigo']

# %%
my_list[0:2]
# Out:
# ['sakigo', 21]

# %%
my_list[2]="Hello"

# %%
my_list
# Out:
# ['sakigo', 21, 'Hello', 78.98]

# %%
my_list.append('world')

# %%
my_list
# Out:
# ['sakigo', 21, 'Hello', 78.98, 'world']

# %%
key1=[9,6,5,4]

# %% [markdown]
# hey

# %%
key1.sort()

# %%
key1
# Out:
# [4, 5, 6, 9]

# %%
type(key1)
# Out:
# list
